# %%
import os

folder_path = r"O:\02.DEPARTMENT\TT\EOE\2025\Raw data"

suffix = "_Nov'25"

for filename in os.listdir(folder_path):
    if filename.lower().endswith((".xlsx", ".xls", ".csv")):
        name, ext = os.path.splitext(filename)

        if name.endswith(suffix):
            continue

        new_name = f"{name}{suffix}{ext}"

        old_path = os.path.join(folder_path, filename)
        new_path = os.path.join(folder_path, new_name)

        os.rename(old_path, new_path)
        print(f"Renamed: {filename} --> {new_name}")

print("Done!")
# Out:
# Renamed: AF19_BAL.csv --> AF19_BAL_Nov'25.csv
# Renamed: AF19_RRO.csv --> AF19_RRO_Nov'25.csv
# Renamed: CK38_BAL.csv --> CK38_BAL_Nov'25.csv
# Renamed: CK38_RRO.csv --> CK38_RRO_Nov'25.csv
# Renamed: EC78_BAL.csv --> EC78_BAL_Nov'25.csv
# Renamed: EC78_CON.csv --> EC78_CON_Nov'25.csv
# Renamed: ES02_BAL.csv --> ES02_BAL_Nov'25.csv
# Renamed: ES02_CON.csv --> ES02_CON_Nov'25.csv
# Renamed: ES60_BAL.csv --> ES60_BAL_Nov'25.csv
# Renamed: ES60_CON.csv --> ES60_CON_Nov'25.csv
# Renamed: ES64_BAL.csv --> ES64_BAL_Nov'25.csv
# Renamed: ES64_CON.csv --> ES64_CON_Nov'25.csv
# Renamed: FM32_BAL.csv --> FM32_BAL_Nov'25.csv
# Renamed: FM32_CON.csv --> FM32_CON_Nov'25.csv
# Done!
